# %%
from keras.models import load_model
import numpy as np
import keras

model = load_model('./quickDrawModel.h5')
-
# Out:
# Using TensorFlow backend.
# Train on 64000 samples, validate on 15998 samples
# Epoch 1/1
# 64000/64000 [==============================] - 203s - loss: 0.6003 - acc: 0.8259 - val_loss: 0.5327 - val_acc: 0.8517

# %%
allTestResults = model.predict(x_test[np.newaxis,0])
print(allTestResults)
error = 1 - allTestResults[0][np.argmax(allTestResults)]
print(error)
# Out:
# [[  2.77477726e-02   2.33724341e-02   3.87929045e-02   2.20184047e-02
#     3.91713083e-02   2.70687211e-02   2.88383663e-03   1.45584773e-02
#     9.16407537e-03   5.71648739e-02   3.78853045e-02   1.19075794e-02
#     1.39647257e-02   1.01038013e-02   9.35970154e-03   9.91095789e-03
#     1.25957265e-01   1.57692228e-02   1.72946882e-02   6.38770964e-03
#     4.22556624e-02   4.89203706e-02   5.07572945e-03   3.53654772e-02
#     3.68644344e-03   1.34320036e-02   5.12807816e-03   2.42595300e-02
#     4.70146909e-02   6.60366118e-02   3.67780291e-02   1.48187634e-02
#     1.10421209e-02   1.04052136e-02   8.45787376e-02   6.92739990e-03
#     4.04700895e-09   4.80667036e-03   1.23011656e-02   6.68344693e-03]]
# 0.874042734504

# %%
allTestResults = model.predict(x_test)
topChoices = np.argmax(allTestResults,axis=-1)
print(topChoices.shape)
# Out:
# (15998,)

# %%
print(topChoices.shape)
print(allTestResults.shape)
indexing = np.arange(allTestResults.shape[0])
print(indexing.shape)
indexing = np.concatenate((indexing[:,np.newaxis],topChoices[:,np.newaxis]),axis=1)
print(indexing.shape)
error =  allTestResults[]
print(error.shape)
# Out:
# (15998,)
# (15998, 40)
# (15998,)
# (15998, 2)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-22ebe940a5d1> in <module>()
#       5 indexing = np.concatenate((indexing[:,np.newaxis],topChoices[:,np.newaxis]),axis=1)
#       6 print(indexing.shape)
# ----> 7 error =  allTestResults[tuple(indexing)]
#       8 print(error.shape)
#
# IndexError: too many indices for array

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

def show_digit(index):
    label =  classes[y_test[index].argmax()]
    # Reshape 784 array into 28x28 image
    image = x_test[index].reshape([28,28])
    fig, axes = plt.subplots(1, )
    fig.subplots_adjust(hspace=0.5, wspace=0.5)
    plt.title('Test data, index: %d,  Label: %s' % (index, label))
    plt.imshow(image, cmap='gray_r')
    plt.show()

indexing = np.arange(allTestResults.shape[0])
error =  allTestResults[np.arange(allTestResults.shape[0]),topChoices]
print(error)
indx = np.argsort(error)

for i in range(10):
    show_digit(indx[i])
    
for i in range(10):
    show_digit(indx[-1*i])


print( classes[y_test[indx[0]].argmax()])

indx[(-1*i)::-1]
# Out:
# [ 0.66666776  0.19266917  0.55129403 ...,  0.8744368   0.99967992  1.        ]
# broom
# array([ 5703, 13632,  5766, ...,  1913,  3053,  2575], dtype=int64)

# %%
indx[-1:-1:15989].shape
# Out:
# (0,)
